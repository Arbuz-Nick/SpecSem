# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
res = pd.read_csv("./../main/result_mpi_polus.csv", sep=';')

# %%
res['TotalTime'] = res['BuildTime'] + res['SearchTime']

# %%
for i in range(len(res)):
    print(res.sort_values(['data_type', 'Nthreads']).iloc[i, :])
# Out:
# BuildTime       0.000248
# SearchTime      0.001491
# Nthreads               1
# data_type           1000
# points_found          16
# TotalTime       0.001739
# Name: 4, dtype: object
# BuildTime       0.000254
# SearchTime       0.00154
# Nthreads               1
# data_type           1000
# points_found          16
# TotalTime       0.001794
# Name: 11, dtype: object
# BuildTime       0.000238
# SearchTime      0.001539
# Nthreads               1
# data_type           1000
# points_found          16
# TotalTime       0.001777
# Name: 24, dtype: object
# BuildTime       0.000257
# SearchTime      0.001525
# Nthreads               1
# data_type           1000
# points_found          16
# TotalTime       0.001782
# Name: 35, dtype: object
# BuildTime       0.000441
# SearchTime        0.0015
# Nthreads               2
# data_type           1000
# points_found          16
# TotalTime       0.001941
# Name: 14, dtype: object
# BuildTime       0.000415
# SearchTime      0.001427
# Nthreads               2
# data_type           1000
# points_found          16
# TotalTime       0.001842
# Name: 53, dtype: object
# BuildTime       0.000513
# SearchTime      0.001435
# Nthreads               2
# data_type           1000
# points_found          16
# TotalTime       0.001948
# Name: 61, dtype: object
# BuildTime       0.000434
# SearchTime      0.001477
# Nthreads               2
# data_type           1000
# points_found          16
# TotalTime       0.001911
# Name: 86, dtype: object
# BuildTime       0.000628
# SearchTime      0.000906
# Nthreads               3
# data_type           1000
# points_found          16
# TotalTime       0.001534
# Name: 99, dtype: object
# BuildTime       0.000591
# SearchTime      0.000869
# Nthreads               3
# data_type           1000
# points_found          16
# TotalTime        0.00146
# Name: 135, dtype: object
# BuildTime       0.000633
# SearchTime      0.001212
# Nthreads               3
# data_type           1000
# points_found          16
# TotalTime       0.001845
# Name: 151, dtype: object
# BuildTime       0.000577
# SearchTime      0.000717
# Nthreads               3
# data_type           1000
# points_found          16
# TotalTime       0.001294
# Name: 163, dtype: object
# BuildTime        0.00076
# SearchTime      0.001018
# Nthreads               4
# data_type           1000
# points_found          16
# TotalTime       0.001778
# Name: 16, dtype: object
# BuildTime       0.000629
# SearchTime      0.000743
# Nthreads               4
# data_type           1000
# points_found          16
# TotalTime       0.001372
# Name: 54, dtype: object
# BuildTime       0.000778
# SearchTime      0.000864
# Nthreads               4
# data_type           1000
# points_found          16
# TotalTime       0.001642
# Name: 79, dtype: object
# BuildTime       0.000867
# SearchTime      0.001241
# Nthreads               4
# data_type           1000
# points_found          16
# TotalTime       0.002108
# Name: 93, dtype: object
# BuildTime       0.000803
# SearchTime      0.000414
# Nthreads               7
# data_type           1000
# points_found          16
# TotalTime       0.001217
# Name: 122, dtype: object
# BuildTime       0.001073
# SearchTime      0.000695
# Nthreads               7
# data_type           1000
# points_found          16
# TotalTime       0.001768
# Name: 138, dtype: object
# BuildTime       0.001007
# SearchTime      0.000623
# Nthreads               7
# data_type           1000
# points_found          16
# TotalTime        0.00163
# Name: 155, dtype: object
# BuildTime       0.000801
# SearchTime      0.000455
# Nthreads               7
# data_type           1000
# points_found          16
# TotalTime       0.001256
# Name: 174, dtype: object
# BuildTime       0.000791
# SearchTime       0.00036
# Nthreads               8
# data_type           1000
# points_found          16
# TotalTime       0.001151
# Name: 25, dtype: object
# BuildTime       0.001319
# SearchTime      0.000634
# Nthreads               8
# data_type           1000
# points_found          16
# TotalTime       0.001953
# Name: 67, dtype: object
# BuildTime       0.001114
# SearchTime      0.000577
# Nthreads               8
# data_type           1000
# points_found          16
# TotalTime       0.001691
# Name: 80, dtype: object
# BuildTime       0.001381
# SearchTime      0.000766
# Nthreads               8
# data_type           1000
# points_found          16
# TotalTime       0.002147
# Name: 109, dtype: object
# BuildTime       0.001435
# SearchTime      0.000555
# Nthreads              15
# data_type           1000
# points_found          17
# TotalTime        0.00199
# Name: 130, dtype: object
# BuildTime       0.002109
# SearchTime      0.000536
# Nthreads              15
# data_type           1000
# points_found          17
# TotalTime       0.002645
# Name: 144, dtype: object
# BuildTime       0.001642
# SearchTime      0.000447
# Nthreads              15
# data_type           1000
# points_found          17
# TotalTime       0.002089
# Name: 158, dtype: object
# BuildTime        0.00154
# SearchTime      0.000541
# Nthreads              15
# data_type           1000
# points_found          17
# TotalTime       0.002081
# Name: 191, dtype: object
# BuildTime       0.001397
# SearchTime      0.000398
# Nthreads              16
# data_type           1000
# points_found          17
# TotalTime       0.001795
# Name: 30, dtype: object
# BuildTime        0.00176
# SearchTime      0.000492
# Nthreads              16
# data_type           1000
# points_found          17
# TotalTime       0.002252
# Name: 68, dtype: object
# BuildTime       0.001047
# SearchTime       0.00038
# Nthreads              16
# data_type           1000
# points_found          17
# TotalTime       0.001427
# Name: 82, dtype: object
# BuildTime        0.00132
# SearchTime      0.000386
# Nthreads              16
# data_type           1000
# points_found          17
# TotalTime       0.001706
# Name: 116, dtype: object
# BuildTime       0.003043
# SearchTime      0.000398
# Nthreads              31
# data_type           1000
# points_found          17
# TotalTime       0.003441
# Name: 171, dtype: object
# BuildTime       0.002538
# SearchTime      0.000385
# Nthreads              31
# data_type           1000
# points_found          17
# TotalTime       0.002923
# Name: 180, dtype: object
# BuildTime       0.001889
# SearchTime       0.00045
# Nthreads              31
# data_type           1000
# points_found          17
# TotalTime       0.002339
# Name: 185, dtype: object
# BuildTime       0.002478
# SearchTime      0.000417
# Nthreads              31
# data_type           1000
# points_found          17
# TotalTime       0.002895
# Name: 197, dtype: object
# BuildTime       0.002569
# SearchTime      0.000397
# Nthreads              32
# data_type           1000
# points_found          17
# TotalTime       0.002966
# Name: 39, dtype: object
# BuildTime       0.001896
# SearchTime      0.000572
# Nthreads              32
# data_type           1000
# points_found          17
# TotalTime       0.002468
# Name: 84, dtype: object
# BuildTime       0.002974
# SearchTime       0.00045
# Nthreads              32
# data_type           1000
# points_found          17
# TotalTime       0.003424
# Name: 102, dtype: object
# BuildTime       0.003465
# SearchTime      0.000536
# Nthreads              32
# data_type           1000
# points_found          17
# TotalTime       0.004001
# Name: 123, dtype: object
# BuildTime       0.002574
# SearchTime      0.019215
# Nthreads               1
# data_type          10000
# points_found         129
# TotalTime       0.021789
# Name: 5, dtype: object
# BuildTime       0.002656
# SearchTime      0.019617
# Nthreads               1
# data_type          10000
# points_found         129
# TotalTime       0.022273
# Name: 12, dtype: object
# BuildTime       0.002439
# SearchTime      0.018251
# Nthreads               1
# data_type          10000
# points_found         129
# TotalTime        0.02069
# Name: 27, dtype: object
# BuildTime       0.002625
# SearchTime      0.021103
# Nthreads               1
# data_type          10000
# points_found         129
# TotalTime       0.023728
# Name: 36, dtype: object
# BuildTime       0.004091
# SearchTime      0.018922
# Nthreads               2
# data_type          10000
# points_found         129
# TotalTime       0.023013
# Name: 18, dtype: object
# BuildTime       0.005046
# SearchTime       0.02133
# Nthreads               2
# data_type          10000
# points_found         129
# TotalTime       0.026376
# Name: 55, dtype: object
# BuildTime        0.00452
# SearchTime      0.022627
# Nthreads               2
# data_type          10000
# points_found         129
# TotalTime       0.027147
# Name: 62, dtype: object
# BuildTime       0.004038
# SearchTime      0.018289
# Nthreads               2
# data_type          10000
# points_found         129
# TotalTime       0.022327
# Name: 88, dtype: object
# BuildTime       0.00685
# SearchTime      0.00948
# Nthreads              3
# data_type         10000
# points_found        129
# TotalTime       0.01633
# Name: 101, dtype: object
# BuildTime         0.0069
# SearchTime      0.008291
# Nthreads               3
# data_type          10000
# points_found         129
# TotalTime       0.015191
# Name: 137, dtype: object
# BuildTime       0.006676
# SearchTime      0.008063
# Nthreads               3
# data_type          10000
# points_found         129
# TotalTime       0.014739
# Name: 154, dtype: object
# BuildTime        0.00814
# SearchTime      0.009526
# Nthreads               3
# data_type          10000
# points_found         129
# TotalTime       0.017666
# Name: 164, dtype: object
# BuildTime       0.006715
# SearchTime        0.0082
# Nthreads               4
# data_type          10000
# points_found         129
# TotalTime       0.014915
# Name: 20, dtype: object
# BuildTime        0.00874
# SearchTime      0.009571
# Nthreads               4
# data_type          10000
# points_found         129
# TotalTime       0.018311
# Name: 56, dtype: object
# BuildTime       0.007444
# SearchTime      0.009831
# Nthreads               4
# data_type          10000
# points_found         129
# TotalTime       0.017275
# Name: 81, dtype: object
# BuildTime       0.009238
# SearchTime      0.016352
# Nthreads               4
# data_type          10000
# points_found         129
# TotalTime        0.02559
# Name: 94, dtype: object
# BuildTime       0.009595
# SearchTime      0.006571
# Nthreads               7
# data_type          10000
# points_found         129
# TotalTime       0.016166
# Name: 124, dtype: object
# BuildTime       0.009517
# SearchTime      0.004061
# Nthreads               7
# data_type          10000
# points_found         129
# TotalTime       0.013578
# Name: 140, dtype: object
# BuildTime       0.00956
# SearchTime      0.00528
# Nthreads              7
# data_type         10000
# points_found        129
# TotalTime       0.01484
# Name: 159, dtype: object
# BuildTime       0.008606
# SearchTime      0.004601
# Nthreads               7
# data_type          10000
# points_found         129
# TotalTime       0.013207
# Name: 175, dtype: object
# BuildTime       0.009657
# SearchTime      0.006563
# Nthreads               8
# data_type          10000
# points_found         129
# TotalTime        0.01622
# Name: 28, dtype: object
# BuildTime        0.00861
# SearchTime      0.004827
# Nthreads               8
# data_type          10000
# points_found         129
# TotalTime       0.013437
# Name: 70, dtype: object
# BuildTime       0.009312
# SearchTime      0.005391
# Nthreads               8
# data_type          10000
# points_found         129
# TotalTime       0.014703
# Name: 83, dtype: object
# BuildTime       0.011728
# SearchTime      0.007022
# Nthreads               8
# data_type          10000
# points_found         129
# TotalTime        0.01875
# Name: 110, dtype: object
# BuildTime       0.010761
# SearchTime      0.003684
# Nthreads              15
# data_type          10000
# points_found         129
# TotalTime       0.014445
# Name: 132, dtype: object
# BuildTime        0.01409
# SearchTime      0.002075
# Nthreads              15
# data_type          10000
# points_found         129
# TotalTime       0.016165
# Name: 146, dtype: object
# BuildTime       0.014209
# SearchTime      0.004808
# Nthreads              15
# data_type          10000
# points_found         129
# TotalTime       0.019017
# Name: 186, dtype: object
# BuildTime       0.013012
# SearchTime      0.002496
# Nthreads              15
# data_type          10000
# points_found         129
# TotalTime       0.015508
# Name: 192, dtype: object
# BuildTime       0.012032
# SearchTime      0.002237
# Nthreads              16
# data_type          10000
# points_found         129
# TotalTime       0.014269
# Name: 31, dtype: object
# BuildTime       0.012838
# SearchTime      0.004287
# Nthreads              16
# data_type          10000
# points_found         129
# TotalTime       0.017125
# Name: 71, dtype: object
# BuildTime       0.012378
# SearchTime      0.003451
# Nthreads              16
# data_type          10000
# points_found         129
# TotalTime       0.015829
# Name: 105, dtype: object
# BuildTime       0.011543
# SearchTime      0.004204
# Nthreads              16
# data_type          10000
# points_found         129
# TotalTime       0.015747
# Name: 125, dtype: object
# BuildTime       0.013412
# SearchTime      0.002674
# Nthreads              31
# data_type          10000
# points_found         130
# TotalTime       0.016086
# Name: 173, dtype: object
# BuildTime       0.013819
# SearchTime      0.002209
# Nthreads              31
# data_type          10000
# points_found         130
# TotalTime       0.016028
# Name: 181, dtype: object
# BuildTime       0.013914
# SearchTime      0.002406
# Nthreads              31
# data_type          10000
# points_found         130
# TotalTime        0.01632
# Name: 188, dtype: object
# BuildTime       0.015753
# SearchTime      0.002873
# Nthreads              31
# data_type          10000
# points_found         130
# TotalTime       0.018626
# Name: 198, dtype: object
# BuildTime       0.013327
# SearchTime      0.001553
# Nthreads              32
# data_type          10000
# points_found         130
# TotalTime        0.01488
# Name: 41, dtype: object
# BuildTime       0.025277
# SearchTime      0.002653
# Nthreads              32
# data_type          10000
# points_found         130
# TotalTime        0.02793
# Name: 87, dtype: object
# BuildTime       0.014994
# SearchTime      0.002521
# Nthreads              32
# data_type          10000
# points_found         130
# TotalTime       0.017515
# Name: 107, dtype: object
# BuildTime       0.014841
# SearchTime      0.002697
# Nthreads              32
# data_type          10000
# points_found         130
# TotalTime       0.017538
# Name: 161, dtype: object
# BuildTime       0.023876
# SearchTime      0.235681
# Nthreads               1
# data_type         100000
# points_found        1172
# TotalTime       0.259557
# Name: 7, dtype: object
# BuildTime       0.024903
# SearchTime      0.233968
# Nthreads               1
# data_type         100000
# points_found        1172
# TotalTime       0.258871
# Name: 15, dtype: object
# BuildTime       0.022902
# SearchTime      0.222221
# Nthreads               1
# data_type         100000
# points_found        1172
# TotalTime       0.245123
# Name: 29, dtype: object
# BuildTime       0.023175
# SearchTime      0.224045
# Nthreads               1
# data_type         100000
# points_found        1172
# TotalTime        0.24722
# Name: 38, dtype: object
# BuildTime       0.035541
# SearchTime      0.220188
# Nthreads               2
# data_type         100000
# points_found        1172
# TotalTime       0.255729
# Name: 32, dtype: object
# BuildTime       0.045233
# SearchTime      0.235232
# Nthreads               2
# data_type         100000
# points_found        1172
# TotalTime       0.280465
# Name: 57, dtype: object
# BuildTime       0.049627
# SearchTime      0.282099
# Nthreads               2
# data_type         100000
# points_found        1172
# TotalTime       0.331726
# Name: 63, dtype: object
# BuildTime       0.041148
# SearchTime      0.254025
# Nthreads               2
# data_type         100000
# points_found        1172
# TotalTime       0.295173
# Name: 90, dtype: object
# BuildTime       0.058867
# SearchTime      0.100658
# Nthreads               3
# data_type         100000
# points_found        1172
# TotalTime       0.159525
# Name: 104, dtype: object
# BuildTime       0.059583
# SearchTime      0.101511
# Nthreads               3
# data_type         100000
# points_found        1172
# TotalTime       0.161094
# Name: 141, dtype: object
# BuildTime       0.059835
# SearchTime      0.101678
# Nthreads               3
# data_type         100000
# points_found        1172
# TotalTime       0.161513
# Name: 156, dtype: object
# BuildTime       0.063884
# SearchTime      0.104764
# Nthreads               3
# data_type         100000
# points_found        1172
# TotalTime       0.168648
# Name: 166, dtype: object
# BuildTime       0.066236
# SearchTime      0.124043
# Nthreads               4
# data_type         100000
# points_found        1172
# TotalTime       0.190279
# Name: 33, dtype: object
# BuildTime       0.066636
# SearchTime      0.115694
# Nthreads               4
# data_type         100000
# points_found        1172
# TotalTime        0.18233
# Name: 58, dtype: object
# BuildTime       0.069466
# SearchTime      0.115548
# Nthreads               4
# data_type         100000
# points_found        1172
# TotalTime       0.185014
# Name: 85, dtype: object
# BuildTime       0.064445
# SearchTime      0.107914
# Nthreads               4
# data_type         100000
# points_found        1172
# TotalTime       0.172359
# Name: 95, dtype: object
# BuildTime       0.082405
# SearchTime      0.050184
# Nthreads               7
# data_type         100000
# points_found        1172
# TotalTime       0.132589
# Name: 126, dtype: object
# BuildTime       0.083355
# SearchTime      0.058074
# Nthreads               7
# data_type         100000
# points_found        1172
# TotalTime       0.141429
# Name: 142, dtype: object
# BuildTime       0.092957
# SearchTime      0.050127
# Nthreads               7
# data_type         100000
# points_found        1172
# TotalTime       0.143084
# Name: 160, dtype: object
# BuildTime        0.07982
# SearchTime      0.053572
# Nthreads               7
# data_type         100000
# points_found        1172
# TotalTime       0.133392
# Name: 177, dtype: object
# BuildTime       0.093578
# SearchTime      0.078645
# Nthreads               8
# data_type         100000
# points_found        1172
# TotalTime       0.172223
# Name: 42, dtype: object
# BuildTime       0.088824
# SearchTime      0.082303
# Nthreads               8
# data_type         100000
# points_found        1172
# TotalTime       0.171127
# Name: 69, dtype: object
# BuildTime       0.082955
# SearchTime      0.058306
# Nthreads               8
# data_type         100000
# points_found        1172
# TotalTime       0.141261
# Name: 106, dtype: object
# BuildTime       0.086098
# SearchTime      0.052322
# Nthreads               8
# data_type         100000
# points_found        1172
# TotalTime        0.13842
# Name: 111, dtype: object
# BuildTime       0.139475
# SearchTime      0.057502
# Nthreads              15
# data_type         100000
# points_found        1172
# TotalTime       0.196977
# Name: 133, dtype: object
# BuildTime       0.109366
# SearchTime      0.025538
# Nthreads              15
# data_type         100000
# points_found        1172
# TotalTime       0.134904
# Name: 147, dtype: object
# BuildTime       0.092273
# SearchTime      0.033124
# Nthreads              15
# data_type         100000
# points_found        1172
# TotalTime       0.125397
# Name: 187, dtype: object
# BuildTime       0.096717
# SearchTime      0.023843
# Nthreads              15
# data_type         100000
# points_found        1172
# TotalTime        0.12056
# Name: 194, dtype: object
# BuildTime       0.124048
# SearchTime      0.028862
# Nthreads              16
# data_type         100000
# points_found        1172
# TotalTime        0.15291
# Name: 43, dtype: object
# BuildTime       0.099843
# SearchTime      0.025122
# Nthreads              16
# data_type         100000
# points_found        1172
# TotalTime       0.124965
# Name: 72, dtype: object
# BuildTime       0.094707
# SearchTime      0.025451
# Nthreads              16
# data_type         100000
# points_found        1172
# TotalTime       0.120158
# Name: 108, dtype: object
# BuildTime       0.092573
# SearchTime      0.027572
# Nthreads              16
# data_type         100000
# points_found        1172
# TotalTime       0.120145
# Name: 127, dtype: object
# BuildTime       0.138442
# SearchTime      0.026657
# Nthreads              31
# data_type         100000
# points_found        1172
# TotalTime       0.165099
# Name: 176, dtype: object
# BuildTime       0.139019
# SearchTime      0.029602
# Nthreads              31
# data_type         100000
# points_found        1172
# TotalTime       0.168621
# Name: 182, dtype: object
# BuildTime       0.147121
# SearchTime      0.026658
# Nthreads              31
# data_type         100000
# points_found        1172
# TotalTime       0.173779
# Name: 189, dtype: object
# BuildTime       0.108843
# SearchTime      0.013436
# Nthreads              31
# data_type         100000
# points_found        1172
# TotalTime       0.122279
# Name: 199, dtype: object
# BuildTime       0.124337
# SearchTime      0.023862
# Nthreads              32
# data_type         100000
# points_found        1172
# TotalTime       0.148199
# Name: 44, dtype: object
# BuildTime       0.121189
# SearchTime      0.029213
# Nthreads              32
# data_type         100000
# points_found        1172
# TotalTime       0.150402
# Name: 89, dtype: object
# BuildTime       0.106104
# SearchTime      0.025682
# Nthreads              32
# data_type         100000
# points_found        1172
# TotalTime       0.131786
# Name: 117, dtype: object
# BuildTime       0.129602
# SearchTime       0.01528
# Nthreads              32
# data_type         100000
# points_found        1172
# TotalTime       0.144882
# Name: 162, dtype: object
# BuildTime        5.44385
# SearchTime       7.01693
# Nthreads               1
# data_type              d
# points_found       35790
# TotalTime       12.46078
# Name: 2, dtype: object
# BuildTime       5.20171
# SearchTime      7.48739
# Nthreads              1
# data_type             d
# points_found      35790
# TotalTime       12.6891
# Name: 17, dtype: object
# BuildTime        5.23829
# SearchTime       6.59929
# Nthreads               1
# data_type              d
# points_found       35790
# TotalTime       11.83758
# Name: 26, dtype: object
# BuildTime        5.16187
# SearchTime        6.8276
# Nthreads               1
# data_type              d
# points_found       35790
# TotalTime       11.98947
# Name: 40, dtype: object
# BuildTime        5.75084
# SearchTime       6.72445
# Nthreads               2
# data_type              d
# points_found       35790
# TotalTime       12.47529
# Name: 3, dtype: object
# BuildTime        5.66456
# SearchTime       6.59165
# Nthreads               2
# data_type              d
# points_found       35790
# TotalTime       12.25621
# Name: 45, dtype: object
# BuildTime        6.49126
# SearchTime       6.96355
# Nthreads               2
# data_type              d
# points_found       35790
# TotalTime       13.45481
# Name: 64, dtype: object
# BuildTime        5.45757
# SearchTime       6.66798
# Nthreads               2
# data_type              d
# points_found       35790
# TotalTime       12.12555
# Name: 75, dtype: object
# BuildTime       6.24974
# SearchTime      3.20719
# Nthreads              3
# data_type             d
# points_found      22022
# TotalTime       9.45693
# Name: 103, dtype: object
# BuildTime       6.63558
# SearchTime       3.1601
# Nthreads              3
# data_type             d
# points_found      22022
# TotalTime       9.79568
# Name: 134, dtype: object
# BuildTime        6.177
# SearchTime      3.3463
# Nthreads             3
# data_type            d
# points_found     22022
# TotalTime       9.5233
# Name: 150, dtype: object
# BuildTime       6.29667
# SearchTime      3.25372
# Nthreads              3
# data_type             d
# points_found      22022
# TotalTime       9.55039
# Name: 167, dtype: object
# BuildTime        6.3562
# SearchTime      3.23384
# Nthreads              4
# data_type             d
# points_found      22022
# TotalTime       9.59004
# Name: 1, dtype: object
# BuildTime       6.16201
# SearchTime      3.14086
# Nthreads              4
# data_type             d
# points_found      22022
# TotalTime       9.30287
# Name: 47, dtype: object
# BuildTime       6.29401
# SearchTime      3.29856
# Nthreads              4
# data_type             d
# points_found      22022
# TotalTime       9.59257
# Name: 66, dtype: object
# BuildTime       6.04383
# SearchTime      3.29305
# Nthreads              4
# data_type             d
# points_found      22022
# TotalTime       9.33688
# Name: 92, dtype: object
# BuildTime       7.01023
# SearchTime      1.63869
# Nthreads              7
# data_type             d
# points_found      22022
# TotalTime       8.64892
# Name: 118, dtype: object
# BuildTime       6.58098
# SearchTime      1.62292
# Nthreads              7
# data_type             d
# points_found      22022
# TotalTime        8.2039
# Name: 136, dtype: object
# BuildTime       7.16842
# SearchTime      1.55554
# Nthreads              7
# data_type             d
# points_found      22022
# TotalTime       8.72396
# Name: 148, dtype: object
# BuildTime       6.64404
# SearchTime      1.60338
# Nthreads              7
# data_type             d
# points_found      22022
# TotalTime       8.24742
# Name: 170, dtype: object
# BuildTime       6.85411
# SearchTime      1.59849
# Nthreads              8
# data_type             d
# points_found      22022
# TotalTime        8.4526
# Name: 0, dtype: object
# BuildTime       7.01551
# SearchTime      1.66547
# Nthreads              8
# data_type             d
# points_found      22022
# TotalTime       8.68098
# Name: 50, dtype: object
# BuildTime       6.62098
# SearchTime      1.57193
# Nthreads              8
# data_type             d
# points_found      22022
# TotalTime       8.19291
# Name: 74, dtype: object
# BuildTime       6.69583
# SearchTime      1.70753
# Nthreads              8
# data_type             d
# points_found      22022
# TotalTime       8.40336
# Name: 113, dtype: object
# BuildTime        7.17808
# SearchTime      0.809045
# Nthreads              15
# data_type              d
# points_found       22022
# TotalTime       7.987125
# Name: 131, dtype: object
# BuildTime         6.7729
# SearchTime      0.788367
# Nthreads              15
# data_type              d
# points_found       22022
# TotalTime       7.561267
# Name: 143, dtype: object
# BuildTime         7.5687
# SearchTime      0.816725
# Nthreads              15
# data_type              d
# points_found       22022
# TotalTime       8.385425
# Name: 152, dtype: object
# BuildTime        7.41627
# SearchTime      0.820184
# Nthreads              15
# data_type              d
# points_found       22022
# TotalTime       8.236454
# Name: 193, dtype: object
# BuildTime        7.06243
# SearchTime      0.770968
# Nthreads              16
# data_type              d
# points_found       22022
# TotalTime       7.833398
# Name: 8, dtype: object
# BuildTime         7.7862
# SearchTime      0.852232
# Nthreads              16
# data_type              d
# points_found       22022
# TotalTime       8.638432
# Name: 51, dtype: object
# BuildTime       7.24725
# SearchTime       0.7933
# Nthreads             16
# data_type             d
# points_found      22022
# TotalTime       8.04055
# Name: 76, dtype: object
# BuildTime        7.17372
# SearchTime      0.786454
# Nthreads              16
# data_type              d
# points_found       22022
# TotalTime       7.960174
# Name: 114, dtype: object
# BuildTime        7.24128
# SearchTime      0.374147
# Nthreads              31
# data_type              d
# points_found       22022
# TotalTime       7.615427
# Name: 168, dtype: object
# BuildTime        7.34535
# SearchTime      0.360461
# Nthreads              31
# data_type              d
# points_found       22022
# TotalTime       7.705811
# Name: 178, dtype: object
# BuildTime        7.36213
# SearchTime      0.359137
# Nthreads              31
# data_type              d
# points_found       22022
# TotalTime       7.721267
# Name: 183, dtype: object
# BuildTime        7.39804
# SearchTime      0.360654
# Nthreads              31
# data_type              d
# points_found       22022
# TotalTime       7.758694
# Name: 195, dtype: object
# BuildTime         7.8261
# SearchTime      0.374528
# Nthreads              32
# data_type              d
# points_found       22022
# TotalTime       8.200628
# Name: 19, dtype: object
# BuildTime        7.24446
# SearchTime      0.427623
# Nthreads              32
# data_type              d
# points_found       22022
# TotalTime       7.672083
# Name: 60, dtype: object
# BuildTime        7.57429
# SearchTime      0.376449
# Nthreads              32
# data_type              d
# points_found       22022
# TotalTime       7.950739
# Name: 97, dtype: object
# BuildTime        7.23559
# SearchTime      0.374057
# Nthreads              32
# data_type              d
# points_found       22022
# TotalTime       7.609647
# Name: 119, dtype: object
# BuildTime       2.05907
# SearchTime      2.82505
# Nthreads              1
# data_type             f
# points_found     211730
# TotalTime       4.88412
# Name: 6, dtype: object
# BuildTime       2.10834
# SearchTime      2.88571
# Nthreads              1
# data_type             f
# points_found     211730
# TotalTime       4.99405
# Name: 10, dtype: object
# BuildTime       2.05358
# SearchTime      2.98731
# Nthreads              1
# data_type             f
# points_found     211730
# TotalTime       5.04089
# Name: 21, dtype: object
# BuildTime       2.03321
# SearchTime      2.85789
# Nthreads              1
# data_type             f
# points_found     211730
# TotalTime        4.8911
# Name: 34, dtype: object
# BuildTime       2.20409
# SearchTime       2.7773
# Nthreads              2
# data_type             f
# points_found     211730
# TotalTime       4.98139
# Name: 9, dtype: object
# BuildTime       2.15266
# SearchTime       2.8654
# Nthreads              2
# data_type             f
# points_found     211730
# TotalTime       5.01806
# Name: 46, dtype: object
# BuildTime       2.30909
# SearchTime      2.95027
# Nthreads              2
# data_type             f
# points_found     211730
# TotalTime       5.25936
# Name: 59, dtype: object
# BuildTime       2.19268
# SearchTime      2.86557
# Nthreads              2
# data_type             f
# points_found     211730
# TotalTime       5.05825
# Name: 91, dtype: object
# BuildTime       2.53986
# SearchTime      1.41494
# Nthreads              3
# data_type             f
# points_found     211730
# TotalTime        3.9548
# Name: 98, dtype: object
# BuildTime       2.47086
# SearchTime      1.35021
# Nthreads              3
# data_type             f
# points_found     211730
# TotalTime       3.82107
# Name: 128, dtype: object
# BuildTime       2.85675
# SearchTime      1.48808
# Nthreads              3
# data_type             f
# points_found     211730
# TotalTime       4.34483
# Name: 149, dtype: object
# BuildTime       2.49711
# SearchTime      1.31653
# Nthreads              3
# data_type             f
# points_found     211730
# TotalTime       3.81364
# Name: 165, dtype: object
# BuildTime       2.51816
# SearchTime      1.43171
# Nthreads              4
# data_type             f
# points_found     211730
# TotalTime       3.94987
# Name: 13, dtype: object
# BuildTime       2.59416
# SearchTime      1.37871
# Nthreads              4
# data_type             f
# points_found     211730
# TotalTime       3.97287
# Name: 49, dtype: object
# BuildTime        2.5331
# SearchTime      1.44423
# Nthreads              4
# data_type             f
# points_found     211730
# TotalTime       3.97733
# Name: 73, dtype: object
# BuildTime       2.64927
# SearchTime       1.3659
# Nthreads              4
# data_type             f
# points_found     211730
# TotalTime       4.01517
# Name: 96, dtype: object
# BuildTime        2.81223
# SearchTime      0.709241
# Nthreads               7
# data_type              f
# points_found      211730
# TotalTime       3.521471
# Name: 121, dtype: object
# BuildTime        2.63225
# SearchTime      0.653848
# Nthreads               7
# data_type              f
# points_found      211730
# TotalTime       3.286098
# Name: 139, dtype: object
# BuildTime       2.60445
# SearchTime      0.69141
# Nthreads              7
# data_type             f
# points_found     211730
# TotalTime       3.29586
# Name: 153, dtype: object
# BuildTime        2.61293
# SearchTime      0.634328
# Nthreads               7
# data_type              f
# points_found      211730
# TotalTime       3.247258
# Name: 172, dtype: object
# BuildTime        2.79534
# SearchTime      0.751724
# Nthreads               8
# data_type              f
# points_found      211730
# TotalTime       3.547064
# Name: 22, dtype: object
# BuildTime        2.79224
# SearchTime      0.656715
# Nthreads               8
# data_type              f
# points_found      211730
# TotalTime       3.448955
# Name: 48, dtype: object
# BuildTime        2.80296
# SearchTime      0.737666
# Nthreads               8
# data_type              f
# points_found      211730
# TotalTime       3.540626
# Name: 77, dtype: object
# BuildTime        2.65911
# SearchTime      0.654358
# Nthreads               8
# data_type              f
# points_found      211730
# TotalTime       3.313468
# Name: 112, dtype: object
# BuildTime        2.9911
# SearchTime      0.35169
# Nthreads             15
# data_type             f
# points_found     211728
# TotalTime       3.34279
# Name: 129, dtype: object
# BuildTime        2.73142
# SearchTime      0.382953
# Nthreads              15
# data_type              f
# points_found      211728
# TotalTime       3.114373
# Name: 145, dtype: object
# BuildTime        2.73076
# SearchTime      0.344439
# Nthreads              15
# data_type              f
# points_found      211728
# TotalTime       3.075199
# Name: 157, dtype: object
# BuildTime        2.85944
# SearchTime      0.340207
# Nthreads              15
# data_type              f
# points_found      211728
# TotalTime       3.199647
# Name: 190, dtype: object
# BuildTime        2.98053
# SearchTime      0.332484
# Nthreads              16
# data_type              f
# points_found      211728
# TotalTime       3.313014
# Name: 23, dtype: object
# BuildTime        2.87054
# SearchTime      0.346871
# Nthreads              16
# data_type              f
# points_found      211728
# TotalTime       3.217411
# Name: 52, dtype: object
# BuildTime        2.94196
# SearchTime      0.347732
# Nthreads              16
# data_type              f
# points_found      211728
# TotalTime       3.289692
# Name: 78, dtype: object
# BuildTime        2.91854
# SearchTime      0.349763
# Nthreads              16
# data_type              f
# points_found      211728
# TotalTime       3.268303
# Name: 115, dtype: object
# BuildTime        3.27307
# SearchTime      0.195558
# Nthreads              31
# data_type              f
# points_found      209057
# TotalTime       3.468628
# Name: 169, dtype: object
# BuildTime         3.0889
# SearchTime      0.183137
# Nthreads              31
# data_type              f
# points_found      209057
# TotalTime       3.272037
# Name: 179, dtype: object
# BuildTime        3.06279
# SearchTime      0.182425
# Nthreads              31
# data_type              f
# points_found      209057
# TotalTime       3.245215
# Name: 184, dtype: object
# BuildTime        2.90267
# SearchTime      0.191693
# Nthreads              31
# data_type              f
# points_found      209057
# TotalTime       3.094363
# Name: 196, dtype: object
# BuildTime        3.12882
# SearchTime      0.197435
# Nthreads              32
# data_type              f
# points_found      209057
# TotalTime       3.326255
# Name: 37, dtype: object
# BuildTime        2.89125
# SearchTime      0.185463
# Nthreads              32
# data_type              f
# points_found      209057
# TotalTime       3.076713
# Name: 65, dtype: object
# BuildTime        2.99374
# SearchTime      0.183642
# Nthreads              32
# data_type              f
# points_found      209057
# TotalTime       3.177382
# Name: 100, dtype: object
# BuildTime         2.9715
# SearchTime      0.190554
# Nthreads              32
# data_type              f
# points_found      209057
# TotalTime       3.162054
# Name: 120, dtype: object

# %%
res = res.groupby(['data_type', 'Nthreads']).mean().reset_index()

# %%
res.to_excel("./result_mpi_polus.xlsx")

# %%
"""
# Loop over each column in the DataFrame
for i, size in enumerate(res.data_type.unique()):
    
    # Select the data for the current column
    data = res[res.data_type == size]
    # data2 = wo_bar_mean[bar_mean.MatrixSize == size]
    
    
    # Plot the data on the corresponding subplot
    sns.lineplot(data=data, x='Nthreads', y='BuildTime')
    sns.lineplot(data=data, x='Nthreads', y='SearchTime')
    sns.lineplot(data=data, x='Nthreads', y='TotalTime')
    plt.show()
    #axes[i].set_title(column)
"""
# Out:
# "\n# Loop over each column in the DataFrame\nfor i, size in enumerate(res.data_type.unique()):\n    \n    # Select the data for the current column\n    data = res[res.data_type == size]\n    # data2 = wo_bar_mean[bar_mean.MatrixSize == size]\n    \n    \n    # Plot the data on the corresponding subplot\n    sns.lineplot(data=data, x='Nthreads', y='BuildTime')\n    sns.lineplot(data=data, x='Nthreads', y='SearchTime')\n    sns.lineplot(data=data, x='Nthreads', y='TotalTime')\n    plt.show()\n    #axes[i].set_title(column)\n"

# %%
new_res = pd.read_excel("./result_mpi_polus.xlsx", index_col=0)

# %%
new_res
# Out:
#    data_type  Nthreads  points_found  build_time  search_time  total_time  \
# 0       1000         1            16    0.000249     0.001524    0.001773
# 1       1000         2            16    0.000451     0.001460    0.001911
# 2       1000         3            16    0.000607     0.000926    0.001533
# 3       1000         4            16    0.000758     0.000967    0.001725
# 4       1000         7            16    0.000921     0.000547    0.001468
# 5       1000         8            16    0.001151     0.000584    0.001736
# 6       1000        15            17    0.001682     0.000520    0.002201
# 7       1000        16            17    0.001381     0.000414    0.001795
# 8       1000        31            17    0.002487     0.000413    0.002899
# 9       1000        32            17    0.002726     0.000489    0.003215
# 10     10000         1           129    0.002573     0.019547    0.022120
# 11     10000         2           129    0.004424     0.020292    0.024716
# 12     10000         3           129    0.007141     0.008840    0.015981
# 13     10000         4           129    0.008034     0.010988    0.019023
# 14     10000         7           129    0.009319     0.005128    0.014448
# 15     10000         8           129    0.009827     0.005951    0.015778
# 16     10000        15           129    0.013018     0.003266    0.016284
# 17     10000        16           129    0.012198     0.003545    0.015743
# 18     10000        31           130    0.014224     0.002541    0.016765
# 19     10000        32           130    0.017110     0.002356    0.019466
# 20    100000         1          1172    0.023714     0.228979    0.252693
# 21    100000         2          1172    0.042887     0.247886    0.290773
# 22    100000         3          1172    0.060542     0.102153    0.162695
# 23    100000         4          1172    0.066696     0.115800    0.182496
# 24    100000         7          1172    0.084634     0.052989    0.137624
# 25    100000         8          1172    0.087864     0.067894    0.155758
# 26    100000        15          1172    0.109458     0.035002    0.144460
# 27    100000        16          1172    0.102793     0.026752    0.129544
# 28    100000        31          1172    0.133356     0.024088    0.157444
# 29    100000        32          1172    0.120308     0.023509    0.143817
# 30         d         1         35790    5.261430     6.982803   12.244233
# 31         d         2         35790    5.841057     6.736908   12.577965
# 32         d         3         22022    6.339747     3.241827    9.581575
# 33         d         4         22022    6.214012     3.241578    9.455590
# 34         d         7         22022    6.850918     1.605133    8.456050
# 35         d         8         22022    6.796608     1.635855    8.432462
# 36         d        15         22022    7.233987     0.808580    8.042568
# 37         d        16         22022    7.317400     0.800739    8.118139
# 38         d        31         22022    7.336700     0.363600    7.700300
# 39         d        32         22022    7.470110     0.388164    7.858274
# 40         f         1        211730    2.063550     2.888990    4.952540
# 41         f         2        211730    2.214630     2.864635    5.079265
# 42         f         3        211730    2.591145     1.392440    3.983585
# 43         f         4        211730    2.573672     1.405137    3.978810
# 44         f         7        211730    2.665465     0.672207    3.337672
# 45         f         8        211730    2.762412     0.700116    3.462528
# 46         f        15        211728    2.828180     0.354822    3.183002
# 47         f        16        211728    2.927893     0.344212    3.272105
# 48         f        31        209057    3.081857     0.188203    3.270061
# 49         f        32        209057    2.996328     0.189274    3.185601
#
#     build_acceleration  search_acceleration  total_acceleration  \
# 0             1.000000             1.000000            1.000000
# 1             0.552882             1.043815            0.927966
# 2             0.410483             1.645406            1.156314
# 3             0.328644             1.576406            1.027781
# 4             0.270627             2.786768            1.207871
# 5             0.216516             2.607674            1.021534
# 6             0.148235             2.932212            0.805443
# 7             0.180492             3.680250            0.987681
# 8             0.100230             3.693545            0.611471
# 9             0.091440             3.117822            0.551508
# 10            1.000000             1.000000            1.000000
# 11            0.581746             0.963261            0.894976
# 12            0.360359             2.211142            1.384103
# 13            0.320313             1.778834            1.162824
# 14            0.276141             3.811577            1.531043
# 15            0.261886             3.284689            1.401992
# 16            0.197686             5.985340            1.358407
# 17            0.210980             5.514233            1.405114
# 18            0.180920             7.693894            1.319418
# 19            0.150410             8.296313            1.136351
# 20            1.000000             1.000000            1.000000
# 21            0.552939             0.923726            0.869037
# 22            0.391693             2.241533            1.553168
# 23            0.355555             1.977368            1.384652
# 24            0.280194             4.321232            1.836115
# 25            0.269895             3.372591            1.622344
# 26            0.216650             6.541918            1.749229
# 27            0.230698             8.559393            1.950626
# 28            0.177825             9.505837            1.604964
# 29            0.197111             9.739953            1.757041
# 30            1.000000             1.000000            1.000000
# 31            0.900767             1.036500            0.973467
# 32            0.829912             2.153971            1.277894
# 33            0.846704             2.154137            1.294920
# 34            0.767989             4.350297            1.447985
# 35            0.774126             4.268595            1.452035
# 36            0.727321             8.635881            1.522428
# 37            0.719030             8.720453            1.508256
# 38            0.717138            19.204641            1.590098
# 39            0.704331            17.989298            1.558132
# 40            1.000000             1.000000            1.000000
# 41            0.931781             1.008502            0.975051
# 42            0.796385             2.074768            1.243237
# 43            0.801792             2.056019            1.244729
# 44            0.774180             4.297770            1.483831
# 45            0.747010             4.126446            1.430325
# 46            0.729639             8.142077            1.555934
# 47            0.704790             8.393042            1.513564
# 48            0.669580            15.350373            1.514510
# 49            0.688693            15.263574            1.554664
#
#     build_efficiency  search_efficiency  total_efficiency
# 0           1.000000           1.000000          1.000000
# 1           0.276441           0.521907          0.463983
# 2           0.136828           0.548469          0.385438
# 3           0.082161           0.394101          0.256945
# 4           0.038661           0.398110          0.172553
# 5           0.027064           0.325959          0.127692
# 6           0.009882           0.195481          0.053696
# 7           0.011281           0.230016          0.061730
# 8           0.003233           0.119147          0.019725
# 9           0.002857           0.097432          0.017235
# 10          1.000000           1.000000          1.000000
# 11          0.290873           0.481631          0.447488
# 12          0.120120           0.737047          0.461368
# 13          0.080078           0.444709          0.290706
# 14          0.039449           0.544511          0.218720
# 15          0.032736           0.410586          0.175249
# 16          0.013179           0.399023          0.090560
# 17          0.013186           0.344640          0.087820
# 18          0.005836           0.248190          0.042562
# 19          0.004700           0.259260          0.035511
# 20          1.000000           1.000000          1.000000
# 21          0.276470           0.461863          0.434519
# 22          0.130564           0.747178          0.517723
# 23          0.088889           0.494342          0.346163
# 24          0.040028           0.617319          0.262302
# 25          0.033737           0.421574          0.202793
# 26          0.014443           0.436128          0.116615
# 27          0.014419           0.534962          0.121914
# 28          0.005736           0.306640          0.051773
# 29          0.006160           0.304374          0.054908
# 30          1.000000           1.000000          1.000000
# 31          0.450383           0.518250          0.486733
# 32          0.276637           0.717990          0.425965
# 33          0.211676           0.538534          0.323730
# 34          0.109713           0.621471          0.206855
# 35          0.096766           0.533574          0.181504
# 36          0.048488           0.575725          0.101495
# 37          0.044939           0.545028          0.094266
# 38          0.023133           0.619505          0.051293
# 39          0.022010           0.562166          0.048692
# 40          1.000000           1.000000          1.000000
# 41          0.465890           0.504251          0.487525
# 42          0.265462           0.691589          0.414412
# 43          0.200448           0.514005          0.311182
# 44          0.110597           0.613967          0.211976
# 45          0.093376           0.515806          0.178791
# 46          0.048643           0.542805          0.103729
# 47          0.044049           0.524565          0.094598
# 48          0.021599           0.495173          0.048855
# 49          0.021522           0.476987          0.048583

# %%
# Loop over each column in the DataFrame
for i, size in enumerate(new_res.data_type.unique()):
    
    # Select the data for the current column
    data = new_res[new_res.data_type == size]
    
    
    f, ax = plt.subplots(1, 1)
    f.set_figwidth(10)
    f.set_figheight(6)
    name = str(size).upper()
    if name == 'D':
        name = 'Fantasy Dragon'
    elif name == 'F':
        name = 'Bearded guy'
    ax.set_title(name)
    ax.set_xlabel("N threads")
    ax.set_ylabel('Time')

    # Plot the data on the corresponding subplot
    sns.lineplot(ax=ax, data=data, x='Nthreads', y='build_time', label='Build')
    sns.lineplot(ax=ax, data=data, x='Nthreads', y='search_time', label='Search')
    sns.lineplot(ax=ax, data=data, x='Nthreads', y='total_time', label='Total')
    
    plt.show()

# %%
# Loop over each column in the DataFrame
for i, size in enumerate(new_res.data_type.unique()):
    
    # Select the data for the current column
    data = new_res[new_res.data_type == size]
    
    
    f, ax = plt.subplots(1, 1)
    f.set_figwidth(10)
    f.set_figheight(6)
    name = str(size).upper()
    if name == 'D':
        name = 'Fantasy Dragon'
    elif name == 'F':
        name = 'Bearded guy'
    ax.set_title(name)
    ax.set_xlabel("N threads")
    ax.set_ylabel('Acceleration')

    # Plot the data on the corresponding subplot
    sns.lineplot(ax=ax, data=data, x='Nthreads', y='build_acceleration', label='Build')
    sns.lineplot(ax=ax, data=data, x='Nthreads', y='search_acceleration', label='Search')
    sns.lineplot(ax=ax, data=data, x='Nthreads', y='total_acceleration', label='Total')
    
    plt.show()

# %%
# Loop over each column in the DataFrame
f, ax = plt.subplots(5, 3)
f.set_figwidth(25)
f.set_figheight(28)
labels = ['Time', 'Acceleration', 'Efficiency']
for j in range(3):
    for i, size in enumerate(new_res.data_type.unique()):
        
        # Select the data for the current column
        data = new_res[new_res.data_type == size]
        
        
        
        
        name = str(size).upper()
        if name == 'D':
            name = 'Fantasy Dragon'
        elif name == 'F':
            name = 'Bearded guy'
        ax[i, j].set_title(name)
        ax[i, j].set_xlabel("N threads")
        ax[i, j].set_ylabel(labels[j])

        # Plot the data on the corresponding subplot
        sns.lineplot(ax=ax[i, j], data=data, x='Nthreads', y='build_' + labels[j].lower(), label='Build')
        sns.lineplot(ax=ax[i, j], data=data, x='Nthreads', y='search_' + labels[j].lower(), label='Search')
        sns.lineplot(ax=ax[i, j], data=data, x='Nthreads', y='total_' + labels[j].lower(), label='Total')


plt.show()

# %%
local = pd.read_csv("./../main/result_mpi_local.csv", sep=';')
local['TotalTime'] = local['BuildTime'] + local['SearchTime']

# %%
local = local.groupby(['data_type', 'Nthreads']).mean().reset_index()

# %%
local.to_excel("./result_mpi_local.xlsx")

# %%
local
# Out:
#    data_type  Nthreads  BuildTime  SearchTime  points_found  TotalTime
# 0       1000         1   0.000107    0.000704          21.0   0.000811
# 1       1000         2   0.000781    0.000655          21.0   0.001436
# 2       1000         3   0.000359    0.000385          21.0   0.000744
# 3       1000         4   0.000427    0.001215          21.0   0.001642
# 4       1000         7   0.032715    0.039009          21.0   0.071725
# 5       1000         8   0.021624    0.031054          21.0   0.052678
# 6       1000        15   0.111599    0.112137          21.0   0.223736
# 7       1000        16   0.078947    0.124643          21.0   0.203590
# 8       1000        31   0.334314    0.460321          21.0   0.794635
# 9       1000        32   0.281960    0.381983          21.0   0.663943
# 10     10000         1   0.001103    0.008571         124.0   0.009674
# 11     10000         2   0.002714    0.007805         124.0   0.010519
# 12     10000         3   0.003647    0.003682         124.0   0.007329
# 13     10000         4   0.004233    0.004180         124.0   0.008413
# 14     10000         7   0.070155    0.023144         124.0   0.093299
# 15     10000         8   0.073898    0.043210         124.0   0.117108
# 16     10000        15   0.400605    0.156779         124.0   0.557384
# 17     10000        16   0.236115    0.158181         124.0   0.394296
# 18     10000        31   0.926953    0.503378         124.0   1.430331
# 19     10000        32   0.639923    0.424923         124.0   1.064846
# 20    100000         1   0.010603    0.116205        1164.0   0.126808
# 21    100000         2   0.028307    0.154041        1164.0   0.182348
# 22    100000         3   0.030377    0.056728        1164.0   0.087105
# 23    100000         4   0.052204    0.081167        1164.0   0.133371
# 24    100000         7   0.137082    0.112101        1164.0   0.249184
# 25    100000         8   0.153227    0.117363        1164.0   0.270590
# 26    100000        15   0.499982    0.273492        1164.0   0.773474
# 27    100000        16   0.491981    0.276582        1164.0   0.768563
# 28    100000        31   1.290024    0.704449        1164.0   1.994473
# 29    100000        32   1.190929    0.930329        1164.0   2.121259
# 30         d         1   3.822665    2.850000       35790.0   6.672665
# 31         d         2   3.409087    2.379583       35790.0   5.788670
# 32         d         3   5.142378    1.661840       35790.0   6.804218
# 33         d         4   3.822637    1.308453       35790.0   5.131090
# 34         d         7  10.627990    1.808572       35790.0  12.436562
# 35         d         8   9.827578    1.940972       35790.0  11.768550
# 36         d        15  22.816700    1.641923       35790.0  24.458623
# 37         d        16  22.857000    1.719052       35790.0  24.576052
# 38         d        31  48.723100    2.466508       35790.0  51.189608
# 39         d        32  48.652700    2.341463       35790.0  50.994163
# 40         f         1   1.674015    1.539700      211730.0   3.213715
# 41         f         2   1.684540    1.379778      211730.0   3.064318
# 42         f         3   1.985320    0.678482      211730.0   2.663802
# 43         f         4   1.810945    0.750983      211730.0   2.561928
# 44         f         7   4.458272    0.742367      211730.0   5.200639
# 45         f         8   4.059143    0.720633      211730.0   4.779775
# 46         f        15  10.836182    1.428605      211730.0  12.264788
# 47         f        16   9.774363    1.055913      211730.0  10.830276
# 48         f        31  28.163100    2.272215      211730.0  30.435315
# 49         f        32  20.110750    1.578050      211730.0  21.688800

# %%
local = pd.read_excel("./result_mpi_local.xlsx", index_col=0)

# %%
local
# Out:
#    data_type  Nthreads  points_found  build_time  search_time  total_time  \
# 0       1000         1            21    0.000107     0.000704    0.000811
# 1       1000         2            21    0.000781     0.000655    0.001436
# 2       1000         3            21    0.000359     0.000385    0.000744
# 3       1000         4            21    0.000427     0.001215    0.001642
# 4       1000         7            21    0.032715     0.039009    0.071725
# 5       1000         8            21    0.021624     0.031054    0.052678
# 6       1000        15            21    0.111599     0.112137    0.223736
# 7       1000        16            21    0.078947     0.124643    0.203590
# 8       1000        31            21    0.334314     0.460321    0.794635
# 9       1000        32            21    0.281960     0.381983    0.663943
# 10     10000         1           124    0.001103     0.008571    0.009674
# 11     10000         2           124    0.002714     0.007805    0.010519
# 12     10000         3           124    0.003647     0.003682    0.007329
# 13     10000         4           124    0.004233     0.004180    0.008413
# 14     10000         7           124    0.070155     0.023144    0.093299
# 15     10000         8           124    0.073898     0.043210    0.117108
# 16     10000        15           124    0.400605     0.156779    0.557384
# 17     10000        16           124    0.236115     0.158181    0.394296
# 18     10000        31           124    0.926953     0.503378    1.430331
# 19     10000        32           124    0.639923     0.424923    1.064846
# 20    100000         1          1164    0.010603     0.116205    0.126808
# 21    100000         2          1164    0.028307     0.154041    0.182348
# 22    100000         3          1164    0.030377     0.056728    0.087105
# 23    100000         4          1164    0.052204     0.081167    0.133371
# 24    100000         7          1164    0.137082     0.112101    0.249184
# 25    100000         8          1164    0.153227     0.117363    0.270590
# 26    100000        15          1164    0.499982     0.273492    0.773474
# 27    100000        16          1164    0.491982     0.276581    0.768563
# 28    100000        31          1164    1.290024     0.704449    1.994473
# 29    100000        32          1164    1.190929     0.930329    2.121259
# 30         d         1         35790    3.822665     2.850000    6.672665
# 31         d         2         35790    3.409088     2.379583    5.788670
# 32         d         3         35790    5.142378     1.661840    6.804218
# 33         d         4         35790    3.822637     1.308453    5.131090
# 34         d         7         35790   10.627990     1.808572   12.436563
# 35         d         8         35790    9.827578     1.940972   11.768550
# 36         d        15         35790   22.816700     1.641922   24.458623
# 37         d        16         35790   22.857000     1.719053   24.576052
# 38         d        31         35790   48.723100     2.466508   51.189608
# 39         d        32         35790   48.652700     2.341463   50.994163
# 40         f         1        211730    1.674015     1.539700    3.213715
# 41         f         2        211730    1.684540     1.379778    3.064318
# 42         f         3        211730    1.985320     0.678482    2.663802
# 43         f         4        211730    1.810945     0.750983    2.561928
# 44         f         7        211730    4.458272     0.742367    5.200639
# 45         f         8        211730    4.059143     0.720633    4.779776
# 46         f        15        211730   10.836182     1.428605   12.264788
# 47         f        16        211730    9.774363     1.055913   10.830276
# 48         f        31        211730   28.163100     2.272215   30.435315
# 49         f        32        211730   20.110750     1.578050   21.688800
#
#     build_acceleration  search_acceleration  total_acceleration  \
# 0             1.000000             1.000000            1.000000
# 1             0.136697             1.074711            0.564568
# 2             0.297163             1.827325            1.088951
# 3             0.250140             0.579290            0.493737
# 4             0.003263             0.018045            0.011303
# 5             0.004937             0.022668            0.015389
# 6             0.000957             0.006277            0.003623
# 7             0.001352             0.005648            0.003982
# 8             0.000319             0.001529            0.001020
# 9             0.000379             0.001843            0.001221
# 10            1.000000             1.000000            1.000000
# 11            0.406460             1.098207            0.919711
# 12            0.302518             2.327529            1.319948
# 13            0.260624             2.050495            1.149916
# 14            0.015726             0.370324            0.103690
# 15            0.014929             0.198357            0.082609
# 16            0.002754             0.054669            0.017356
# 17            0.004672             0.054184            0.024535
# 18            0.001190             0.017027            0.006764
# 19            0.001724             0.020171            0.009085
# 20            1.000000             1.000000            1.000000
# 21            0.374586             0.754373            0.695417
# 22            0.349051             2.048468            1.455806
# 23            0.203112             1.431679            0.950793
# 24            0.077349             1.036603            0.508893
# 25            0.069200             0.990127            0.468635
# 26            0.021207             0.424892            0.163946
# 27            0.021552             0.420147            0.164994
# 28            0.008219             0.164958            0.063580
# 29            0.008903             0.124907            0.059780
# 30            1.000000             1.000000            1.000000
# 31            1.121316             1.197689            1.152711
# 32            0.743365             1.714967            0.980666
# 33            1.000007             2.178146            1.300438
# 34            0.359679             1.575828            0.536536
# 35            0.388973             1.468336            0.566991
# 36            0.167538             1.735770            0.272814
# 37            0.167243             1.657890            0.271511
# 38            0.078457             1.155480            0.130352
# 39            0.078570             1.217188            0.130852
# 40            1.000000             1.000000            1.000000
# 41            0.993752             1.115905            1.048754
# 42            0.843197             2.269331            1.206439
# 43            0.924388             2.050245            1.254413
# 44            0.375485             2.074043            0.617946
# 45            0.412406             2.136594            0.672357
# 46            0.154484             1.077764            0.262028
# 47            0.171266             1.458169            0.296734
# 48            0.059440             0.677621            0.105592
# 49            0.083240             0.975698            0.148174
#
#     build_efficiency  search_efficiency  total_efficiency
# 0           1.000000           1.000000          1.000000
# 1           0.068348           0.537356          0.282284
# 2           0.099054           0.609108          0.362984
# 3           0.062535           0.144822          0.123434
# 4           0.000466           0.002578          0.001615
# 5           0.000617           0.002833          0.001924
# 6           0.000064           0.000418          0.000242
# 7           0.000085           0.000353          0.000249
# 8           0.000010           0.000049          0.000033
# 9           0.000012           0.000058          0.000038
# 10          1.000000           1.000000          1.000000
# 11          0.203230           0.549103          0.459855
# 12          0.100839           0.775843          0.439983
# 13          0.065156           0.512624          0.287479
# 14          0.002247           0.052903          0.014813
# 15          0.001866           0.024795          0.010326
# 16          0.000184           0.003645          0.001157
# 17          0.000292           0.003387          0.001533
# 18          0.000038           0.000549          0.000218
# 19          0.000054           0.000630          0.000284
# 20          1.000000           1.000000          1.000000
# 21          0.187293           0.377187          0.347709
# 22          0.116350           0.682823          0.485269
# 23          0.050778           0.357920          0.237698
# 24          0.011050           0.148086          0.072699
# 25          0.008650           0.123766          0.058579
# 26          0.001414           0.028326          0.010930
# 27          0.001347           0.026259          0.010312
# 28          0.000265           0.005321          0.002051
# 29          0.000278           0.003903          0.001868
# 30          1.000000           1.000000          1.000000
# 31          0.560658           0.598845          0.576356
# 32          0.247788           0.571656          0.326889
# 33          0.250002           0.544536          0.325110
# 34          0.051383           0.225118          0.076648
# 35          0.048622           0.183542          0.070874
# 36          0.011169           0.115718          0.018188
# 37          0.010453           0.103618          0.016969
# 38          0.002531           0.037274          0.004205
# 39          0.002455           0.038037          0.004089
# 40          1.000000           1.000000          1.000000
# 41          0.496876           0.557952          0.524377
# 42          0.281066           0.756444          0.402146
# 43          0.231097           0.512561          0.313603
# 44          0.053641           0.296292          0.088278
# 45          0.051551           0.267074          0.084045
# 46          0.010299           0.071851          0.017469
# 47          0.010704           0.091136          0.018546
# 48          0.001917           0.021859          0.003406
# 49          0.002601           0.030491          0.004630

# %%
# Loop over each column in the DataFrame
f, ax = plt.subplots(5, 3)
f.set_figwidth(25)
f.set_figheight(28)
labels = ['Time', 'Acceleration', 'Efficiency']
for j in range(3):
    for i, size in enumerate(local.data_type.unique()):
        
        # Select the data for the current column
        data = local[local.data_type == size]
        
        name = str(size).upper()
        if name == 'D':
            name = 'Fantasy Dragon'
        elif name == 'F':
            name = 'Bearded guy'
        ax[i, j].set_title(name)
        ax[i, j].set_xlabel("N threads")
        ax[i, j].set_ylabel(labels[j])

        # Plot the data on the corresponding subplot
        sns.lineplot(ax=ax[i, j], data=data, x='Nthreads', y='build_' + labels[j].lower(), label='Build')
        sns.lineplot(ax=ax[i, j], data=data, x='Nthreads', y='search_' + labels[j].lower(), label='Search')
        sns.lineplot(ax=ax[i, j], data=data, x='Nthreads', y='total_' + labels[j].lower(), label='Total')


plt.show()
